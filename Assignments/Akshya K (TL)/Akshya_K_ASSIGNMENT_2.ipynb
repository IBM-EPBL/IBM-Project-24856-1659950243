# %%
import random
from time import sleep
while True:
 t= random.randint(1,50)
 print("Temperature=",t)
 h= random.randint(1,50)
 print("Humid=",h)
 if(t>=50 and h<35):
   print("On")
 else:
   print("Off")
 sleep(3)
# Out:
# Temperature= 16
# Humid= 9
# Off
# Temperature= 50
# Humid= 5
# On
# Temperature= 3
# Humid= 24
# Off
# Temperature= 33
# Humid= 43
# Off
# Temperature= 47
# Humid= 29
# Off
# Temperature= 25
# Humid= 33
# Off
# Temperature= 36
# Humid= 12
# Off
# Temperature= 39
# Humid= 49
# Off
# Temperature= 3
# Humid= 17
# Off
# Temperature= 23
# Humid= 2
# Off
# Temperature= 7
# Humid= 21
# Off
# Temperature= 28
# Humid= 28
# Off
# Temperature= 4
# Humid= 40
# Off
# Temperature= 28
# Humid= 30
# Off
# Temperature= 35
# Humid= 28
# Off
# Temperature= 22
# Humid= 8
# Off
# Temperature= 8
# Humid= 19
# Off
# Temperature= 41
# Humid= 40
# Off
# Temperature= 34
# Humid= 39
# Off
# Temperature= 19
# Humid= 8
# Off
# Temperature= 47
# Humid= 13
# Off
# Temperature= 16
# Humid= 6
# Off
# Temperature= 9
# Humid= 38
# Off
# Temperature= 23
# Humid= 11
# Off
# Temperature= 50
# Humid= 4
# On
# Temperature= 37
# Humid= 46
# Off
# Temperature= 8
# Humid= 21
# Off
# Temperature= 30
# Humid= 6
# Off
# ...
